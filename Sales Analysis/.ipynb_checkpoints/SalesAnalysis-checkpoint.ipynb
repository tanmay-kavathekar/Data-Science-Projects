# %% [markdown]
# # Sales Analysis

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

# %% [markdown]
# ### Merge the 12 months of Data into single task

# %%
df=pd.DataFrame()

files=[file for file in os.listdir('./Sales_Data/')]

for file in files:
    tmp=pd.read_csv("./Sales_Data/"+file)
    df=pd.concat([df,tmp])
    
df.to_csv('./Output/all_data.csv',index=False)
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ### Cleanup data

# %% [markdown]
# #### Drop NaN

# %%
nan_df= df[df.isnull().any(axis=1)]
nan_df.head()

df.dropna(how='all',inplace=True)

# %% [markdown]
# #### Find or and delete it

# %%
df = df[df['Order Date'].str[0:2] != 'Or']
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ### Augment data with additional columns

# %% [markdown]
# #### Add Month Column

# %%
df['Month']=df['Order Date'].str[0:2]
df['Month']=df['Month'].astype('int8')
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# #### Add Sales Column

# %%
df['Quantity Ordered']=pd.to_numeric(df['Quantity Ordered'])
df['Price Each']=pd.to_numeric(df['Price Each'])

# %%
df['Sales']=df['Quantity Ordered']*df['Price Each']
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %% [markdown]
# #### Add City Column

# %%
city_df=df['Purchase Address'].str.split(pat=',',expand=True)
df['City']=city_df[1]
state_df=city_df[2].str.split(expand=True)
df['State']=state_df[0]
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#            City State
# 0        Dallas    TX
# 1        Boston    MA
# 2   Los Angeles    CA
# 3   Los Angeles    CA
# 4   Los Angeles    CA

# %% [markdown]
# #### Add Order Time Column

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Hour']=df['Order Date'].dt.hour
df['Minute']=df['Order Date'].dt.minute
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 1 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 2 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#            City State  Hour  Minute
# 0        Dallas    TX     8      46
# 1        Boston    MA    22      30
# 2   Los Angeles    CA    14      38
# 3   Los Angeles    CA    14      38
# 4   Los Angeles    CA     9      27

# %% [markdown]
# #### Best Sales month and Earning that month

# %%
results= df.groupby('Month',as_index=False).sum()
display(results)
# Out:
#     Month  Quantity Ordered    Price Each         Sales    Hour  Minute
# 0       1             10903  1.811768e+06  1.822257e+06  139485  282440
# 1       2             13449  2.188885e+06  2.202022e+06  172669  354885
# 2       3             17005  2.791208e+06  2.807100e+06  218969  447559
# 3       4             20558  3.367671e+06  3.390670e+06  262259  544186
# 4       5             18667  3.135125e+06  3.152607e+06  238780  487899
# 5       6             15253  2.562026e+06  2.577802e+06  195528  402436
# 6       7             16072  2.632540e+06  2.647776e+06  206169  417349
# 7       8             13448  2.230345e+06  2.244468e+06  172289  353857
# 8       9             13109  2.084992e+06  2.097560e+06  168513  341698
# 9      10             22703  3.715555e+06  3.736727e+06  290650  598437
# 10     11             19798  3.180601e+06  3.199603e+06  254865  518231
# 11     12             28114  4.588415e+06  4.613443e+06  359978  733082

# %%
sns.barplot(data=results,x=results['Month'],y=results['Sales'])
plt.xlabel('Months')
plt.ylabel('Sales in CAD')
plt.show()

# %% [markdown]
# #### City with highest sales

# %%
results= df.groupby('City',as_index=False).sum()
display(results)
# Out:
#              City  Quantity Ordered    Price Each     Month         Sales  \
# 0         Atlanta             16602  2.779908e+06  104794.0  2.795499e+06
# 1          Austin             11153  1.809874e+06   69829.0  1.819582e+06
# 2          Boston             22528  3.637410e+06  141112.0  3.661642e+06
# 3          Dallas             16730  2.752628e+06  104620.0  2.767975e+06
# 4     Los Angeles             33289  5.421435e+06  208325.0  5.452571e+06
# 5   New York City             27932  4.635371e+06  175741.0  4.664317e+06
# 6        Portland             14053  2.307747e+06   87765.0  2.320491e+06
# 7   San Francisco             50239  8.211462e+06  315520.0  8.262204e+06
# 8         Seattle             16553  2.733296e+06  104941.0  2.747755e+06
#
#      Hour   Minute
# 0  214264   442932
# 1  141946   289060
# 2  288225   590442
# 3  214390   435155
# 4  427444   866638
# 5  357696   733598
# 6  179632   368389
# 7  643265  1319477
# 8  213292   436368

# %%
sns.set(rc={"figure.figsize":(10,7)})
sns.barplot(data=results,x=results['City'],y=results['Sales'])
plt.xlabel('City')
plt.ylabel('Sales in CAD')
plt.show()

# %% [markdown]
# #### What time should the advertisements be displayed for maximizing likelihood of customer buying product

# %%
results=df.groupby('Hour',as_index=False).sum()
display(results)
# Out:
#     Hour  Quantity Ordered  Price Each    Month       Sales  Minute
# 0      0              4428   709296.70  27554.0   713721.27  103596
# 1      1              2619   458490.00  16657.0   460866.88   61807
# 2      2              1398   233833.64   8507.0   234851.44   32508
# 3      3               928   144726.42   5904.0   145757.89   23044
# 4      4               937   162058.18   6148.0   162661.01   26876
# 5      5              1493   229621.21   9301.0   230679.82   42877
# 6      6              2810   445000.11  17539.0   448113.00   80343
# 7      7              4556   740568.11  28850.0   744854.12  127447
# 8      8              7002  1185970.62  43626.0  1192348.97  198135
# 9      9              9816  1628498.49  60981.0  1639030.58  268253
# 10    10             12308  1932665.62  76928.0  1944286.77  331941
# 11    11             14005  2288855.18  87654.0  2300610.24  368952
# 12    12             14202  2299876.68  89161.0  2316821.34  368679
# 13    13             13685  2139743.86  85808.0  2155389.80  351045
# 14    14             12362  2072194.77  77836.0  2083672.73  322563
# 15    15             11391  1931174.99  72060.0  1941549.60  299893
# 16    16             11662  1892454.54  72939.0  1904601.31  310132
# 17    17             12229  2116777.02  77454.0  2129361.61  323428
# 18    18             13802  2207696.93  86421.0  2219348.30  371688
# 19    19             14470  2398588.31  91389.0  2412938.54  381042
# 20    20             13768  2268185.16  86375.0  2281716.24  354086
# 21    21             12244  2030763.83  77103.0  2042000.86  312062
# 22    22              9899  1599464.44  62088.0  1607549.21  248503
# 23    23              7065  1172625.87  44364.0  1179304.44  173159

# %%
sns.lineplot(data=results,x=results['Hour'],y=results['Quantity Ordered'])
plt.xticks(results['Hour'])
plt.ylabel('Sales in CAD')
plt.grid()
plt.show()

# %% [markdown]
# #### Products sold together

# %%
#order_id_df=df.loc[:,['Order ID']]
order_id_df=df[df['Order ID'].duplicated(keep=False)]
display(order_id_df.head(20))
order_id_df['Grouped products']=order_id_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
order_id_df.head()
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 2     176560                Google Phone                 1      600.00
# 3     176560            Wired Headphones                 1       11.99
# 17    176574                Google Phone                 1      600.00
# 18    176574        USB-C Charging Cable                 1       11.95
# 29    176585  Bose SoundSport Headphones                 1       99.99
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176586      AAA Batteries (4-pack)                 2        2.99
# 32    176586                Google Phone                 1      600.00
# 118   176672    Lightning Charging Cable                 1       14.95
# 119   176672        USB-C Charging Cable                 1       11.95
# 128   176681    Apple Airpods Headphones                 1      150.00
# 129   176681             ThinkPad Laptop                 1      999.99
# 137   176689  Bose SoundSport Headphones                 1       99.99
# 138   176689      AAA Batteries (4-pack)                 2        2.99
# 188   176739      34in Ultrawide Monitor                 1      379.99
# 189   176739                Google Phone                 1      600.00
# 224   176774    Lightning Charging Cable                 1       14.95
# 225   176774        USB-C Charging Cable                 1       11.95
# 232   176781                      iPhone                 1      700.00
# 233   176781    Lightning Charging Cable                 1       14.95
#
#              Order Date                         Purchase Address  Month  \
# 2   2019-04-12 14:38:00     669 Spruce St, Los Angeles, CA 90001      4
# 3   2019-04-12 14:38:00     669 Spruce St, Los Angeles, CA 90001      4
# 17  2019-04-03 19:42:00        20 Hill St, Los Angeles, CA 90001      4
# 18  2019-04-03 19:42:00        20 Hill St, Los Angeles, CA 90001      4
# 29  2019-04-07 11:31:00        823 Highland St, Boston, MA 02215      4
# 30  2019-04-07 11:31:00        823 Highland St, Boston, MA 02215      4
# 31  2019-04-10 17:00:00   365 Center St, San Francisco, CA 94016      4
# 32  2019-04-10 17:00:00   365 Center St, San Francisco, CA 94016      4
# 118 2019-04-12 11:07:00    778 Maple St, New York City, NY 10001      4
# 119 2019-04-12 11:07:00    778 Maple St, New York City, NY 10001      4
# 128 2019-04-20 10:39:00         331 Cherry St, Seattle, WA 98101      4
# 129 2019-04-20 10:39:00         331 Cherry St, Seattle, WA 98101      4
# 137 2019-04-24 17:15:00  659 Lincoln St, New York City, NY 10001      4
# 138 2019-04-24 17:15:00  659 Lincoln St, New York City, NY 10001      4
# 188 2019-04-05 17:38:00             730 6th St, Austin, TX 73301      4
# 189 2019-04-05 17:38:00             730 6th St, Austin, TX 73301      4
# 224 2019-04-25 15:06:00     372 Church St, Los Angeles, CA 90001      4
# 225 2019-04-25 15:06:00     372 Church St, Los Angeles, CA 90001      4
# 232 2019-04-03 07:37:00         976 Hickory St, Dallas, TX 75001      4
# 233 2019-04-03 07:37:00         976 Hickory St, Dallas, TX 75001      4
#
#       Sales            City State  Hour  Minute
# 2    600.00     Los Angeles    CA    14      38
# 3     11.99     Los Angeles    CA    14      38
# 17   600.00     Los Angeles    CA    19      42
# 18    11.95     Los Angeles    CA    19      42
# 29    99.99          Boston    MA    11      31
# 30    99.99          Boston    MA    11      31
# 31     5.98   San Francisco    CA    17       0
# 32   600.00   San Francisco    CA    17       0
# 118   14.95   New York City    NY    11       7
# 119   11.95   New York City    NY    11       7
# 128  150.00         Seattle    WA    10      39
# 129  999.99         Seattle    WA    10      39
# 137   99.99   New York City    NY    17      15
# 138    5.98   New York City    NY    17      15
# 188  379.99          Austin    TX    17      38
# 189  600.00          Austin    TX    17      38
# 224   14.95     Los Angeles    CA    15       6
# 225   11.95     Los Angeles    CA    15       6
# 232  700.00          Dallas    TX     7      37
# 233   14.95          Dallas    TX     7      37
# C:\Users\priya\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 17   176574                Google Phone                 1      600.00
# 18   176574        USB-C Charging Cable                 1       11.95
# 29   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address  Month   Sales  \
# 2  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 17 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001      4  600.00
# 18 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001      4   11.95
# 29 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215      4   99.99
#
#             City State  Hour  Minute  \
# 2    Los Angeles    CA    14      38
# 3    Los Angeles    CA    14      38
# 17   Los Angeles    CA    19      42
# 18   Los Angeles    CA    19      42
# 29        Boston    MA    11      31
#
#                                      Grouped products
# 2                       Google Phone,Wired Headphones
# 3                       Google Phone,Wired Headphones
# 17                  Google Phone,USB-C Charging Cable
# 18                  Google Phone,USB-C Charging Cable
# 29  Bose SoundSport Headphones,Bose SoundSport Hea...
